# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('car_price_dataset.csv')

# %%
data.head()
# Out:
#         Brand   Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 0         Kia     Rio  2020          4.2    Diesel          Manual   289944
# 1   Chevrolet  Malibu  2012          2.0    Hybrid       Automatic     5356
# 2    Mercedes     GLA  2020          4.2    Diesel       Automatic   231440
# 3        Audi      Q5  2023          2.0  Electric          Manual   160971
# 4  Volkswagen    Golf  2003          2.6    Hybrid  Semi-Automatic   286618
#
#    Doors  Owner_Count  Price
# 0      3            5   8501
# 1      2            3  12092
# 2      4            2  11171
# 3      2            1  11780
# 4      3            3   2867

# %%
data.tail()
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 9995     5794      2            4   8884
# 9996   168000      2            1   6240
# 9997    86664      5            1   9866
# 9998   225772      4            1   4084
# 9999   157882      3            3   3342

# %%
data.shape
# Out:
# (10000, 10)

# %%
print("number of columns",data.shape[0])
print("number of rows",data.shape[1])
# Out:
# number of columns 10000
# number of rows 10

# %%
data.isnull().sum()
# Out:
# Brand           0
# Model           0
# Year            0
# Engine_Size     0
# Fuel_Type       0
# Transmission    0
# Mileage         0
# Doors           0
# Owner_Count     0
# Price           0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         10000 non-null  object
#  1   Model         10000 non-null  object
#  2   Year          10000 non-null  int64
#  3   Engine_Size   10000 non-null  float64
#  4   Fuel_Type     10000 non-null  object
#  5   Transmission  10000 non-null  object
#  6   Mileage       10000 non-null  int64
#  7   Doors         10000 non-null  int64
#  8   Owner_Count   10000 non-null  int64
#  9   Price         10000 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 781.4+ KB

# %%
data.describe()
# Out:
#                Year   Engine_Size        Mileage         Doors   Owner_Count  \
# count  10000.000000  10000.000000   10000.000000  10000.000000  10000.000000
# mean    2011.543700      3.000560  149239.111800      3.497100      2.991100
# std        6.897699      1.149324   86322.348957      1.110097      1.422682
# min     2000.000000      1.000000      25.000000      2.000000      1.000000
# 25%     2006.000000      2.000000   74649.250000      3.000000      2.000000
# 50%     2012.000000      3.000000  149587.000000      3.000000      3.000000
# 75%     2017.000000      4.000000  223577.500000      4.000000      4.000000
# max     2023.000000      5.000000  299947.000000      5.000000      5.000000
#
#              Price
# count  10000.00000
# mean    8852.96440
# std     3112.59681
# min     2000.00000
# 25%     6646.00000
# 50%     8858.50000
# 75%    11086.50000
# max    18301.00000

# %%
cat=[]
num=[]
for column in data.columns:
    if data[column].nunique()>10:
        num.append(column)
    else:
        cat.append(column)

# %%
num
# Out:
# ['Model', 'Year', 'Engine_Size', 'Mileage', 'Price']

# %%
cat
# Out:
# ['Brand', 'Fuel_Type', 'Transmission', 'Doors', 'Owner_Count']

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %% [markdown]
# #CATEGORICAL

# %%
data['Brand'].value_counts().plot(kind='pie',autopct="%1.2f%%")
plt.title("percentage  of each brand")
# Out:
# Text(0.5, 1.0, 'percentage  of each brand')

# %%
data['Brand'].value_counts()
# Out:
# Ford          1048
# Audi          1038
# Volkswagen    1020
# Honda         1009
# Chevrolet     1003
# BMW            999
# Hyundai        995
# Kia            976
# Toyota         970
# Mercedes       942
# Name: Brand, dtype: int64

# %%
data['Brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # we can se that percentage of Ford brand is hoghest while mercedes is lowest

# %%
data['Fuel_Type'].value_counts()
# Out:
# Electric    2625
# Diesel      2512
# Hybrid      2453
# Petrol      2410
# Name: Fuel_Type, dtype: int64

# %%
data['Fuel_Type'].value_counts().plot(kind='pie',autopct="%1.2f%%")
plt.title("percentage of Fuel_Type")
# Out:
# Text(0.5, 1.0, 'percentage of Fuel_Type')

# %% [markdown]
# # order of fuel type :-Electric>Diesel>Hybrid>Petrol

# %%
data['Transmission'].value_counts()
# Out:
# Manual            3372
# Automatic         3317
# Semi-Automatic    3311
# Name: Transmission, dtype: int64

# %%
data['Transmission'].value_counts().plot(kind='bar')
plt.title("barplot showing the numbers of transmission type")
# Out:
# Text(0.5, 1.0, 'barplot showing the numbers of transmission type')

# %% [markdown]
# # MANUAL>AUTOMATIC>SEMI-AUTOMATIC

# %%
data['Doors'].value_counts().plot(kind='pie',autopct="%1.2f%%")
# Out:
# <Axes: ylabel='Doors'>

# %%
data['Doors'].value_counts()
# Out:
# 3    2575
# 4    2514
# 5    2456
# 2    2455
# Name: Doors, dtype: int64

# %% [markdown]
# # count of 3 doors vehicle is highest

# %%
data['Owner_Count'].value_counts()
# Out:
# 5    2036
# 1    2036
# 2    2020
# 3    1977
# 4    1931
# Name: Owner_Count, dtype: int64

# %%
data['Owner_Count'].value_counts().plot(kind='pie',autopct="%1.2f%%")
# Out:
# <Axes: ylabel='Owner_Count'>

# %% [markdown]
# # 5 owner count>1 owner count>2 owner count>3 owner count>4 owner count

# %% [markdown]
# # univariate analysis for numerical

# %%
num
# Out:
# ['Model', 'Year', 'Engine_Size', 'Mileage', 'Price']

# %%
sns.distplot(data['Engine_Size'])
plt.title("distribution of engine_size")
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_6440\1865163035.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Engine_Size'])
# Text(0.5, 1.0, 'distribution of engine_size')

# %%
data["Engine_Size"].skew()
# Out:
# -0.008234989306448845

# %% [markdown]
# # we can see that engine_size are normally distributed and skewness is almost zero

# %%
sns.distplot(data['Mileage'])
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_6440\1471309030.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Mileage'])
# <Axes: xlabel='Mileage', ylabel='Density'>

# %%
data['Mileage'].skew()
# Out:
# 0.0009187712262495086

# %% [markdown]
# # Mileage are normally distributed and skewness is equal to zero

# %%
sns.distplot(data["Price"])
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_6440\4278785232.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Price"])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
data['Price'].skew()
# Out:
# 0.026136215676512354

# %%
data['Price'].describe()
# Out:
# count    10000.00000
# mean      8852.96440
# std       3112.59681
# min       2000.00000
# 25%       6646.00000
# 50%       8858.50000
# 75%      11086.50000
# max      18301.00000
# Name: Price, dtype: float64

# %%
data['Mileage'].describe()
# Out:
# count     10000.000000
# mean     149239.111800
# std       86322.348957
# min          25.000000
# 25%       74649.250000
# 50%      149587.000000
# 75%      223577.500000
# max      299947.000000
# Name: Mileage, dtype: float64

# %%
data['Engine_Size'].describe()
# Out:
# count    10000.000000
# mean         3.000560
# std          1.149324
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: Engine_Size, dtype: float64

# %%
sns.boxplot(data['Price'])
# Out:
# <Axes: >

# %%
sns.boxplot(data['Mileage'])
# Out:
# <Axes: >

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ## Numerical--Numericall

# %%
num
# Out:
# ['Model', 'Year', 'Engine_Size', 'Mileage', 'Price']

# %%
sns.scatterplot(data=data,x="Year",y="Price")
plt.title("relation of price with year")
# Out:
# Text(0.5, 1.0, 'relation of price with year')

# %% [markdown]
# # we can see that price is increasing with increasing year

# %%
sns.scatterplot(data=data,x="Year",y="Engine_Size")
# Out:
# <Axes: xlabel='Year', ylabel='Engine_Size'>

# %% [markdown]
# # there is no relation between Engine_size and year as every Engine_size is availabe in every Year

# %%
sns.scatterplot(data=data,x="Year",y="Mileage")
# Out:
# <Axes: xlabel='Year', ylabel='Mileage'>

# %% [markdown]
# # there is no relation between mileage and year as every Mileage is availabe in every Year¶

# %%
sns.scatterplot(data=data,x="Mileage",y="Engine_Size")
# Out:
# <Axes: xlabel='Mileage', ylabel='Engine_Size'>

# %%
sns.scatterplot(data=data,x="Mileage",y="Price")
# Out:
# <Axes: xlabel='Mileage', ylabel='Price'>

# %% [markdown]
# # there is a inveerse relation between Mileage and Price

# %%
sns.scatterplot(data=data,x="Price",y="Engine_Size")
# Out:
# <Axes: xlabel='Price', ylabel='Engine_Size'>

# %% [markdown]
# ## Categorical -- Numerical

# %%
cat
# Out:
# ['Brand', 'Fuel_Type', 'Transmission', 'Doors', 'Owner_Count']

# %%
num
# Out:
# ['Model', 'Year', 'Engine_Size', 'Mileage', 'Price']

# %%
sns.barplot(data=data,x="Fuel_Type",y="Price")
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Price'>

# %% [markdown]
# # we can conclude that price of fuel Type Electric>Hybrid>Petrol>Diesel

# %%
sns.barplot(data=data,x="Transmission",y="Price")
# Out:
# <Axes: xlabel='Transmission', ylabel='Price'>

# %% [markdown]
# # we can conclude that price of Automatic transmission > Manual transmission> Semi-Automatic

# %%
sns.barplot(data=data,x="Brand",y="Price")
# Out:
# <Axes: xlabel='Brand', ylabel='Price'>

# %% [markdown]
# # hence price of each brand is approximately same

# %%
sns.barplot(data=data,x="Brand",y="Mileage")
# Out:
# <Axes: xlabel='Brand', ylabel='Mileage'>

# %% [markdown]
# # mileage is also approx same in each brand  but highest in Honda

# %%
sns.barplot(data=data,x="Transmission",y="Mileage")
# Out:
# <Axes: xlabel='Transmission', ylabel='Mileage'>

# %% [markdown]
# # mileage is also approx same but highest in semi automatic

# %%
sns.barplot(data=data,x="Transmission",y="Year")
# Out:
# <Axes: xlabel='Transmission', ylabel='Year'>

# %%
sns.barplot(data=data,x="Fuel_Type",y="Mileage")
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Mileage'>

# %% [markdown]
# # Categorical --- Categorical

# %%
cat
# Out:
# ['Brand', 'Fuel_Type', 'Transmission', 'Doors', 'Owner_Count']

# %%
pd.crosstab(data['Brand'],data['Fuel_Type'])
# Out:
# Fuel_Type   Diesel  Electric  Hybrid  Petrol
# Brand
# Audi           248       262     280     248
# BMW            245       279     217     258
# Chevrolet      260       250     257     236
# Ford           264       278     258     248
# Honda          248       265     256     240
# Hyundai        250       255     253     237
# Kia            260       244     242     230
# Mercedes       251       249     216     226
# Toyota         246       268     224     232
# Volkswagen     240       275     250     255

# %% [markdown]
# # Electric fuel type is most common among different brands

# %%
pd.crosstab(data['Brand'],data['Transmission'])
# Out:
# Transmission  Automatic  Manual  Semi-Automatic
# Brand
# Audi                343     353             342
# BMW                 340     325             334
# Chevrolet           357     330             316
# Ford                347     337             364
# Honda               327     356             326
# Hyundai             330     336             329
# Kia                 324     332             320
# Mercedes            314     337             291
# Toyota              292     326             352
# Volkswagen          343     340             337

# %% [markdown]
# # Audi,Honda,Hyundai,kia,merceded have highest number of manual car.chevrolet,toyota,volkswagen has highest number of automatic car and remaing have most number of semi -automatic car

# %%
pd.crosstab(data['Brand'],data['Owner_Count'])
# Out:
# Owner_Count    1    2    3    4    5
# Brand
# Audi         214  217  217  189  201
# BMW          240  219  187  176  177
# Chevrolet    205  195  201  198  204
# Ford         215  188  199  231  215
# Honda        211  201  197  198  202
# Hyundai      177  230  196  193  199
# Kia          175  183  183  217  218
# Mercedes     188  187  193  164  210
# Toyota       187  197  192  193  201
# Volkswagen   224  203  212  172  209

# %%
pd.crosstab(data['Fuel_Type'],data['Transmission'])
# Out:
# Transmission  Automatic  Manual  Semi-Automatic
# Fuel_Type
# Diesel              827     846             839
# Electric            881     893             851
# Hybrid              819     817             817
# Petrol              790     816             804

# %%
sns.heatmap(pd.crosstab(data['Fuel_Type'],data['Transmission']))
# Out:
# <Axes: xlabel='Transmission', ylabel='Fuel_Type'>

# %% [markdown]
# # diesel,electric,petrol have most manual car while hybrid have most automatic car

# %% [markdown]
# ## MultiVariate Analysis

# %%
cat
# Out:
# ['Brand', 'Fuel_Type', 'Transmission', 'Doors', 'Owner_Count']

# %%
num
# Out:
# ['Model', 'Year', 'Engine_Size', 'Mileage', 'Price']

# %%
sns.barplot(data=data,x="Fuel_Type",y="Price",hue="Brand")
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Price'>

# %%
sns.barplot(data=data,x="Fuel_Type",y="Price",hue="Transmission")
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Price'>

# %%
sns.barplot(data=data,x="Fuel_Type",y="Year",hue="Brand")
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Year'>
